# %% [markdown]
# # Laboratorio 2 - Clasificador de rostros

# %% [markdown]
# **Autores**
#
# *   [214205] Enrique, Oliva
# *   [192680] Martina, Severo
# *   [229484] Santiago, Tonarelli

# %% [markdown]
# **Formato de entrega**:
#
# * Esta misma notebook en formato .ipynb
# * Cambiar el nombre de la notebook por NumEst1_NumEst2_NumEst3_Lab_1.
# * Es importante que la notebook pueda ejecutarse sin problemas al seleccionar 'Ejecutar todo'.
# * Se considerará que sus datos pueden estar en otra localización.
#
#
# **Plazo de entrega**: hasta el Domingo 16/06 a las 23:59 horas a través de Aulas.

# %% [markdown]
# **Objetivo**: implementar un algoritmo de clasificación que permita predecir si una imagen dada es un rostro o no.

# %% [markdown]
# ## Librerías

# %%
import os
from tqdm import tqdm
from time import time

import random
import numpy as np
import matplotlib.pyplot as plt

from skimage.exposure import equalize_hist

from skimage.transform import integral_image
from skimage.feature import haar_like_feature, haar_like_feature_coord

from sklearn.feature_selection import SelectPercentile, f_classif

# %% [markdown]
# ## Funciones auxiliares

# %%
def extract_feature_image(img, feature_type=None, feature_coord=None):
    """Extrae las Haar features de la imagen"""
    ii = integral_image(img)
    return haar_like_feature(ii, 0, 0, ii.shape[0], ii.shape[1],
                             feature_type=feature_type,
                             feature_coord=feature_coord)

# %% [markdown]
# ## Datos

# %% [markdown]
# **CBCL FACE DATABASE #1**:
#
# *   19 x 19 Grayscale PGM format images
# *   Training set:  2429 faces, 4548 non-faces
# *   Test set: 472 faces, 23573 non-faces

# %%
# !unzip /content/CBCL.zip
# !tar -xvzf /content/face.test.tar.gz
# !tar -xvzf /content/face.train.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# train/face/face01979.pgm
# train/face/face01980.pgm
# train/face/face01981.pgm
# train/face/face01982.pgm
# train/face/face01983.pgm
# train/face/face01984.pgm
# train/face/face01985.pgm
# train/face/face01986.pgm
# train/face/face01987.pgm
# train/face/face01988.pgm
# train/face/face01989.pgm
# train/face/face01990.pgm
# train/face/face01991.pgm
# train/face/face01992.pgm
# train/face/face01993.pgm
# train/face/face01994.pgm
# train/face/face01995.pgm
# train/face/face01996.pgm
# train/face/face01997.pgm
# train/face/face01998.pgm
# train/face/face01999.pgm
# train/face/face02000.pgm
# train/face/face02001.pgm
# train/face/face02002.pgm
# train/face/face02003.pgm
# train/face/face02004.pgm
# train/face/face02005.pgm
# train/face/face02006.pgm
# train/face/face02007.pgm
# train/face/face02008.pgm
# train/face/face02009.pgm
# train/face/face02010.pgm
# train/face/face02011.pgm
# train/face/face02012.pgm
# train/face/face02013.pgm
# train/face/face02014.pgm
# train/face/face02015.pgm
# train/face/face02016.pgm
# train/face/face02017.pgm
# train/face/face02018.pgm
# train/face/face02019.pgm
# train/face/face02020.pgm
# train/face/face02021.pgm
# train/face/face02022.pgm
# train/face/face02023.pgm
# train/face/face02024.pgm
# train/face/face02025.pgm
# train/face/face02026.pgm
# train/face/face02027.pgm
# train/face/face02028.pgm
# train/face/face02029.pgm
# train/face/face02030.pgm
# train/face/face02031.pgm
# train/face/face02032.pgm
# train/face/face02033.pgm
# train/face/face02034.pgm
# train/face/face02035.pgm
# train/face/face02036.pgm
# train/face/face02037.pgm
# train/face/face02038.pgm
# train/face/face02039.pgm
# train/face/face02040.pgm
# train/face/face02041.pgm
# train/face/face02042.pgm
# train/face/face02043.pgm
# train/face/face02044.pgm
# train/face/face02045.pgm
# train/face/face02046.pgm
# train/face/face02047.pgm
# train/face/face02048.pgm
# train/face/face02049.pgm
# train/face/face02050.pgm
# train/face/face02051.pgm
# train/face/face02052.pgm
# train/face/face02053.pgm
# train/face/face02054.pgm
# train/face/face02055.pgm
# train/face/face02056.pgm
# train/face/face02057.pgm
# train/face/face02058.pgm
# train/face/face02059.pgm
# train/face/face02060.pgm
# train/face/face02061.pgm
# train/face/face02062.pgm
# train/face/face02063.pgm
# train/face/face02064.pgm
# train/face/face02065.pgm
# train/face/face02066.pgm
# train/face/face02067.pgm
# train/face/face02068.pgm
# train/face/face02069.pgm
# train/face/face02070.pgm
# train/face/face02071.pgm
# train/face/face02072.pgm
# train/face/face02073.pgm
# train/face/face02074.pgm
# train/face/face02075.pgm
# train/face/face02076.pgm
# train/face/face02077.pgm
# train/face/face02078.pgm
# train/face/face02079.pgm
# train/face/face02080.pgm
# train/face/face02081.pgm
# train/face/face02082.pgm
# train/face/face02083.pgm
# train/face/face02084.pgm
# train/face/face02085.pgm
# train/face/face02086.pgm
# train/face/face02087.pgm
# train/face/face02088.pgm
# train/face/face02089.pgm
# train/face/face02090.pgm
# train/face/face02091.pgm
# train/face/face02092.pgm
# train/face/face02093.pgm
# train/face/face02094.pgm
# train/face/face02095.pgm
# train/face/face02096.pgm
# train/face/face02097.pgm
# train/face/face02098.pgm
# train/face/face02099.pgm
# train/face/face02100.pgm
# train/face/face02101.pgm
# train/face/face02102.pgm
# train/face/face02103.pgm
# train/face/face02104.pgm
# train/face/face02105.pgm
# train/face/face02106.pgm
# train/face/face02107.pgm
# train/face/face02108.pgm
# train/face/face02109.pgm
# train/face/face02110.pgm
# train/face/face02111.pgm
# train/face/face02112.pgm
# train/face/face02113.pgm
# train/face/face02114.pgm
# train/face/face02115.pgm
# train/face/face02116.pgm
# train/face/face02117.pgm
# train/face/face02118.pgm
# train/face/face02119.pgm
# train/face/face02120.pgm
# train/face/face02121.pgm
# train/face/face02122.pgm
# train/face/face02123.pgm
# train/face/face02124.pgm
# train/face/face02125.pgm
# train/face/face02126.pgm
# train/face/face02127.pgm
# train/face/face02128.pgm
# train/face/face02129.pgm
# train/face/face02130.pgm
# train/face/face02131.pgm
# train/face/face02132.pgm
# train/face/face02133.pgm
# train/face/face02134.pgm
# train/face/face02135.pgm
# train/face/face02136.pgm
# train/face/face02137.pgm
# train/face/face02138.pgm
# train/face/face02139.pgm
# train/face/face02140.pgm
# train/face/face02141.pgm
# train/face/face02142.pgm
# train/face/face02143.pgm
# train/face/face02144.pgm
# train/face/face02145.pgm
# train/face/face02146.pgm
# train/face/face02147.pgm
# train/face/face02148.pgm
# train/face/face02149.pgm
# train/face/face02150.pgm
# train/face/face02151.pgm
# train/face/face02152.pgm
# train/face/face02153.pgm
# train/face/face02154.pgm
# train/face/face02155.pgm
# train/face/face02156.pgm
# train/face/face02157.pgm
# train/face/face02158.pgm
# train/face/face02159.pgm
# train/face/face02160.pgm
# train/face/face02161.pgm
# train/face/face02162.pgm
# train/face/face02163.pgm
# train/face/face02164.pgm
# train/face/face02165.pgm
# train/face/face02166.pgm
# train/face/face02167.pgm
# train/face/face02168.pgm
# train/face/face02169.pgm
# train/face/face02170.pgm
# train/face/face02171.pgm
# train/face/face02172.pgm
# train/face/face02173.pgm
# train/face/face02174.pgm
# train/face/face02175.pgm
# train/face/face02176.pgm
# train/face/face02177.pgm
# train/face/face02178.pgm
# train/face/face02179.pgm
# train/face/face02180.pgm
# train/face/face02181.pgm
# train/face/face02182.pgm
# train/face/face02183.pgm
# train/face/face02184.pgm
# train/face/face02185.pgm
# train/face/face02186.pgm
# train/face/face02187.pgm
# train/face/face02188.pgm
# train/face/face02189.pgm
# train/face/face02190.pgm
# train/face/face02191.pgm
# train/face/face02192.pgm
# train/face/face02193.pgm
# train/face/face02194.pgm
# train/face/face02195.pgm
# train/face/face02196.pgm
# train/face/face02197.pgm
# train/face/face02198.pgm
# train/face/face02199.pgm
# train/face/face02200.pgm
# train/face/face02201.pgm
# train/face/face02202.pgm
# train/face/face02203.pgm
# train/face/face02204.pgm
# train/face/face02205.pgm
# train/face/face02206.pgm
# train/face/face02207.pgm
# train/face/face02208.pgm
# train/face/face02209.pgm
# train/face/face02210.pgm
# train/face/face02211.pgm
# train/face/face02212.pgm
# train/face/face02213.pgm
# train/face/face02214.pgm
# train/face/face02215.pgm
# train/face/face02216.pgm
# train/face/face02217.pgm
# train/face/face02218.pgm
# train/face/face02219.pgm
# train/face/face02220.pgm
# train/face/face02221.pgm
# train/face/face02222.pgm
# train/face/face02223.pgm
# train/face/face02224.pgm
# train/face/face02225.pgm
# train/face/face02226.pgm
# train/face/face02227.pgm
# train/face/face02228.pgm
# train/face/face02229.pgm
# train/face/face02230.pgm
# train/face/face02231.pgm
# train/face/face02232.pgm
# train/face/face02233.pgm
# train/face/face02234.pgm
# train/face/face02235.pgm
# train/face/face02236.pgm
# train/face/face02237.pgm
# train/face/face02238.pgm
# train/face/face02239.pgm
# train/face/face02240.pgm
# train/face/face02241.pgm
# train/face/face02242.pgm
# train/face/face02243.pgm
# train/face/face02244.pgm
# train/face/face02245.pgm
# train/face/face02246.pgm
# train/face/face02247.pgm
# train/face/face02248.pgm
# train/face/face02249.pgm
# train/face/face02250.pgm
# train/face/face02251.pgm
# train/face/face02252.pgm
# train/face/face02253.pgm
# train/face/face02254.pgm
# train/face/face02255.pgm
# train/face/face02256.pgm
# train/face/face02257.pgm
# train/face/face02258.pgm
# train/face/face02259.pgm
# train/face/face02260.pgm
# train/face/face02261.pgm
# train/face/face02262.pgm
# train/face/face02263.pgm
# train/face/face02264.pgm
# train/face/face02265.pgm
# train/face/face02266.pgm
# train/face/face02267.pgm
# train/face/face02268.pgm
# train/face/face02269.pgm
# train/face/face02270.pgm
# train/face/face02271.pgm
# train/face/face02272.pgm
# train/face/face02273.pgm
# train/face/face02274.pgm
# train/face/face02275.pgm
# train/face/face02276.pgm
# train/face/face02277.pgm
# train/face/face02278.pgm
# train/face/face02279.pgm
# train/face/face02280.pgm
# train/face/face02281.pgm
# train/face/face02282.pgm
# train/face/face02283.pgm
# train/face/face02284.pgm
# train/face/face02285.pgm
# train/face/face02286.pgm
# train/face/face02287.pgm
# train/face/face02288.pgm
# train/face/face02289.pgm
# train/face/face02290.pgm
# train/face/face02291.pgm
# train/face/face02292.pgm
# train/face/face02293.pgm
# train/face/face02294.pgm
# train/face/face02295.pgm
# train/face/face02296.pgm
# train/face/face02297.pgm
# train/face/face02298.pgm
# train/face/face02299.pgm
# train/face/face02300.pgm
# train/face/face02301.pgm
# train/face/face02302.pgm
# train/face/face02303.pgm
# train/face/face02304.pgm
# train/face/face02305.pgm
# train/face/face02306.pgm
# train/face/face02307.pgm
# train/face/face02308.pgm
# train/face/face02309.pgm
# train/face/face02310.pgm
# train/face/face02311.pgm
# train/face/face02312.pgm
# train/face/face02313.pgm
# train/face/face02314.pgm
# train/face/face02315.pgm
# train/face/face02316.pgm
# train/face/face02317.pgm
# train/face/face02318.pgm
# train/face/face02319.pgm
# train/face/face02320.pgm
# train/face/face02321.pgm
# train/face/face02322.pgm
# train/face/face02323.pgm
# train/face/face02324.pgm
# train/face/face02325.pgm
# train/face/face02326.pgm
# train/face/face02327.pgm
# train/face/face02328.pgm
# train/face/face02329.pgm
# train/face/face02330.pgm
# train/face/face02331.pgm
# train/face/face02332.pgm
# train/face/face02333.pgm
# train/face/face02334.pgm
# train/face/face02335.pgm
# train/face/face02336.pgm
# train/face/face02337.pgm
# train/face/face02338.pgm
# train/face/face02339.pgm
# train/face/face02340.pgm
# train/face/face02341.pgm
# train/face/face02342.pgm
# train/face/face02343.pgm
# train/face/face02344.pgm
# train/face/face02345.pgm
# train/face/face02346.pgm
# train/face/face02347.pgm
# train/face/face02348.pgm
# train/face/face02349.pgm
# train/face/face02350.pgm
# train/face/face02351.pgm
# train/face/face02352.pgm
# train/face/face02353.pgm
# train/face/face02354.pgm
# train/face/face02355.pgm
# train/face/face02356.pgm
# train/face/face02357.pgm
# train/face/face02358.pgm
# train/face/face02359.pgm
# train/face/face02360.pgm
# train/face/face02361.pgm
# train/face/face02362.pgm
# train/face/face02363.pgm
# train/face/face02364.pgm
# train/face/face02365.pgm
# train/face/face02366.pgm
# train/face/face02367.pgm
# train/face/face02368.pgm
# train/face/face02369.pgm
# train/face/face02370.pgm
# train/face/face02371.pgm
# train/face/face02372.pgm
# train/face/face02373.pgm
# train/face/face02374.pgm
# train/face/face02375.pgm
# train/face/face02376.pgm
# train/face/face02377.pgm
# train/face/face02378.pgm
# train/face/face02379.pgm
# train/face/face02380.pgm
# train/face/face02381.pgm
# train/face/face02382.pgm
# train/face/face02383.pgm
# train/face/face02384.pgm
# train/face/face02385.pgm
# train/face/face02386.pgm
# train/face/face02387.pgm
# train/face/face02388.pgm
# train/face/face02389.pgm
# train/face/face02390.pgm
# train/face/face02391.pgm
# train/face/face02392.pgm
# train/face/face02393.pgm
# train/face/face02394.pgm
# train/face/face02395.pgm
# train/face/face02396.pgm
# train/face/face02397.pgm
# train/face/face02398.pgm
# train/face/face02399.pgm
# train/face/face02400.pgm
# train/face/face02401.pgm
# train/face/face02402.pgm
# train/face/face02403.pgm
# train/face/face02404.pgm
# train/face/face02405.pgm
# train/face/face02406.pgm
# train/face/face02407.pgm
# train/face/face02408.pgm
# train/face/face02409.pgm
# train/face/face02410.pgm
# train/face/face02411.pgm
# train/face/face02412.pgm
# train/face/face02413.pgm
# train/face/face02414.pgm
# train/face/face02415.pgm
# train/face/face02416.pgm
# train/face/face02417.pgm
# train/face/face02418.pgm
# train/face/face02419.pgm
# train/face/face02420.pgm
# train/face/face02421.pgm
# train/face/face02422.pgm
# train/face/face02423.pgm
# train/face/face02424.pgm
# train/face/face02425.pgm
# train/face/face02426.pgm
# train/face/face02427.pgm
# train/face/face02428.pgm
# train/face/face02429.pgm
# train/non-face/
# train/non-face/B1_00001.pgm
# train/non-face/B1_00002.pgm
# train/non-face/B1_00003.pgm
# train/non-face/B1_00004.pgm
# train/non-face/B1_00005.pgm
# train/non-face/B1_00006.pgm
# train/non-face/B1_00007.pgm
# train/non-face/B1_00008.pgm
# train/non-face/B1_00009.pgm
# train/non-face/B1_00010.pgm
# train/non-face/B1_00011.pgm
# train/non-face/B1_00012.pgm
# train/non-face/B1_00013.pgm
# train/non-face/B1_00014.pgm
# train/non-face/B1_00015.pgm
# train/non-face/B1_00016.pgm
# train/non-face/B1_00017.pgm
# train/non-face/B1_00018.pgm
# train/non-face/B1_00019.pgm
# train/non-face/B1_00020.pgm
# train/non-face/B1_00021.pgm
# train/non-face/B1_00022.pgm
# train/non-face/B1_00023.pgm
# train/non-face/B1_00024.pgm
# train/non-face/B1_00025.pgm
# train/non-face/B1_00026.pgm
# train/non-face/B1_00027.pgm
# train/non-face/B1_00028.pgm
# train/non-face/B1_00029.pgm
# train/non-face/B1_00030.pgm
# train/non-face/B1_00031.pgm
# train/non-face/B1_00032.pgm
# train/non-face/B1_00033.pgm
# train/non-face/B1_00034.pgm
# train/non-face/B1_00035.pgm
# train/non-face/B1_00036.pgm
# train/non-face/B1_00037.pgm
# train/non-face/B1_00038.pgm
# train/non-face/B1_00039.pgm
# train/non-face/B1_00040.pgm
# train/non-face/B1_00041.pgm
# train/non-face/B1_00042.pgm
# train/non-face/B1_00043.pgm
# train/non-face/B1_00044.pgm
# train/non-face/B1_00045.pgm
# train/non-face/B1_00046.pgm
# train/non-face/B1_00047.pgm
# train/non-face/B1_00048.pgm
# train/non-face/B1_00049.pgm
# train/non-face/B1_00050.pgm
# train/non-face/B1_00051.pgm
# train/non-face/B1_00052.pgm
# train/non-face/B1_00053.pgm
# train/non-face/B1_00054.pgm
# train/non-face/B1_00055.pgm
# train/non-face/B1_00056.pgm
# train/non-face/B1_00057.pgm
# train/non-face/B1_00058.pgm
# train/non-face/B1_00059.pgm
# train/non-face/B1_00060.pgm
# train/non-face/B1_00061.pgm
# train/non-face/B1_00062.pgm
# train/non-face/B1_00063.pgm
# train/non-face/B1_00064.pgm
# train/non-face/B1_00065.pgm
# train/non-face/B1_00066.pgm
# train/non-face/B1_00067.pgm
# train/non-face/B1_00068.pgm
# train/non-face/B1_00069.pgm
# train/non-face/B1_00070.pgm
# train/non-face/B1_00071.pgm
# train/non-face/B1_00072.pgm
# train/non-face/B1_00073.pgm
# train/non-face/B1_00074.pgm
# train/non-face/B1_00075.pgm
# train/non-face/B1_00076.pgm
# train/non-face/B1_00077.pgm
# train/non-face/B1_00078.pgm
# train/non-face/B1_00079.pgm
# train/non-face/B1_00080.pgm
# train/non-face/B1_00081.pgm
# train/non-face/B1_00082.pgm
# train/non-face/B1_00083.pgm
# train/non-face/B1_00084.pgm
# train/non-face/B1_00085.pgm
# train/non-face/B1_00086.pgm
# train/non-face/B1_00087.pgm
# train/non-face/B1_00088.pgm
# train/non-face/B1_00089.pgm
# train/non-face/B1_00090.pgm
# train/non-face/B1_00091.pgm
# train/non-face/B1_00092.pgm
# train/non-face/B1_00093.pgm
# train/non-face/B1_00094.pgm
# train/non-face/B1_00095.pgm
# train/non-face/B1_00096.pgm
# train/non-face/B1_00097.pgm
# train/non-face/B1_00098.pgm
# train/non-face/B1_00099.pgm
# train/non-face/B1_00100.pgm
# train/non-face/B1_00101.pgm
# train/non-face/B1_00102.pgm
# train/non-face/B1_00103.pgm
# train/non-face/B1_00104.pgm
# train/non-face/B1_00105.pgm
# train/non-face/B1_00106.pgm
# train/non-face/B1_00107.pgm
# train/non-face/B1_00108.pgm
# train/non-face/B1_00109.pgm
# train/non-face/B1_00110.pgm
# train/non-face/B1_00111.pgm
# train/non-face/B1_00112.pgm
# train/non-face/B1_00113.pgm
# train/non-face/B1_00114.pgm
# train/non-face/B1_00115.pgm
# train/non-face/B1_00116.pgm
# train/non-face/B1_00117.pgm
# train/non-face/B1_00118.pgm
# train/non-face/B1_00119.pgm
# train/non-face/B1_00120.pgm
# train/non-face/B1_00121.pgm
# train/non-face/B1_00122.pgm
# train/non-face/B1_00123.pgm
# train/non-face/B1_00124.pgm
# train/non-face/B1_00125.pgm
# train/non-face/B1_00126.pgm
# train/non-face/B1_00127.pgm
# train/non-face/B1_00128.pgm
# train/non-face/B1_00129.pgm
# train/non-face/B1_00130.pgm
# train/non-face/B1_00131.pgm
# train/non-face/B1_00132.pgm
# train/non-face/B1_00133.pgm
# train/non-face/B1_00134.pgm
# train/non-face/B1_00135.pgm
# train/non-face/B1_00136.pgm
# train/non-face/B1_00137.pgm
# train/non-face/B1_00138.pgm
# train/non-face/B1_00139.pgm
# train/non-face/B1_00140.pgm
# train/non-face/B1_00141.pgm
# train/non-face/B1_00142.pgm
# train/non-face/B1_00143.pgm
# train/non-face/B1_00144.pgm
# train/non-face/B1_00145.pgm
# train/non-face/B1_00146.pgm
# train/non-face/B1_00147.pgm
# train/non-face/B1_00148.pgm
# train/non-face/B1_00149.pgm
# train/non-face/B1_00150.pgm
# train/non-face/B1_00151.pgm
# train/non-face/B1_00152.pgm
# train/non-face/B1_00153.pgm
# train/non-face/B1_00154.pgm
# train/non-face/B1_00155.pgm
# train/non-face/B1_00156.pgm
# train/non-face/B1_00157.pgm
# train/non-face/B1_00158.pgm
# train/non-face/B1_00159.pgm
# train/non-face/B1_00160.pgm
# train/non-face/B1_00161.pgm
# train/non-face/B1_00162.pgm
# train/non-face/B1_00163.pgm
# train/non-face/B1_00164.pgm
# train/non-face/B1_00165.pgm
# train/non-face/B1_00166.pgm
# train/non-face/B1_00167.pgm
# train/non-face/B1_00168.pgm
# train/non-face/B1_00169.pgm
# train/non-face/B1_00170.pgm
# train/non-face/B1_00171.pgm
# train/non-face/B1_00172.pgm
# train/non-face/B1_00173.pgm
# train/non-face/B1_00174.pgm
# train/non-face/B1_00175.pgm
# train/non-face/B1_00176.pgm
# train/non-face/B1_00177.pgm
# train/non-face/B1_00178.pgm
# train/non-face/B1_00179.pgm
# train/non-face/B1_00180.pgm
# train/non-face/B1_00181.pgm
# train/non-face/B1_00182.pgm
# train/non-face/B1_00183.pgm
# train/non-face/B1_00184.pgm
# train/non-face/B1_00185.pgm
# train/non-face/B1_00186.pgm
# train/non-face/B1_00187.pgm
# train/non-face/B1_00188.pgm
# train/non-face/B1_00189.pgm
# train/non-face/B1_00190.pgm
# train/non-face/B1_00191.pgm
# train/non-face/B1_00192.pgm
# train/non-face/B1_00193.pgm
# train/non-face/B1_00194.pgm
# train/non-face/B1_00195.pgm
# train/non-face/B1_00196.pgm
# train/non-face/B1_00197.pgm
# train/non-face/B1_00198.pgm
# train/non-face/B1_00199.pgm
# train/non-face/B1_00200.pgm
# train/non-face/B1_00201.pgm
# train/non-face/B1_00202.pgm
# train/non-face/B1_00203.pgm
# train/non-face/B1_00204.pgm
# train/non-face/B1_00205.pgm
# train/non-face/B1_00206.pgm
# train/non-face/B1_00207.pgm
# train/non-face/B1_00208.pgm
# train/non-face/B1_00209.pgm
# train/non-face/B1_00210.pgm
# train/non-face/B1_00211.pgm
# train/non-face/B1_00212.pgm
# train/non-face/B1_00213.pgm
# train/non-face/B1_00214.pgm
# train/non-face/B1_00215.pgm
# train/non-face/B1_00216.pgm
# train/non-face/B1_00217.pgm
# train/non-face/B1_00218.pgm
# train/non-face/B1_00219.pgm
# train/non-face/B1_00220.pgm
# train/non-face/B1_00221.pgm
# train/non-face/B1_00222.pgm
# train/non-face/B1_00223.pgm
# train/non-face/B1_00224.pgm
# train/non-face/B1_00225.pgm
# train/non-face/B1_00226.pgm
# train/non-face/B1_00227.pgm
# train/non-face/B1_00228.pgm
# train/non-face/B1_00229.pgm
# train/non-face/B1_00230.pgm
# train/non-face/B1_00231.pgm
# train/non-face/B1_00232.pgm
# train/non-face/B1_00233.pgm
# train/non-face/B1_00234.pgm
# train/non-face/B1_00235.pgm
# train/non-face/B1_00236.pgm
# train/non-face/B1_00237.pgm
# train/non-face/B1_00238.pgm
# train/non-face/B1_00239.pgm
# train/non-face/B1_00240.pgm
# train/non-face/B1_00241.pgm
# train/non-face/B1_00242.pgm
# train/non-face/B1_00243.pgm
# train/non-face/B1_00244.pgm
# train/non-face/B1_00245.pgm
# train/non-face/B1_00246.pgm
# train/non-face/B1_00247.pgm
# train/non-face/B1_00248.pgm
# train/non-face/B1_00249.pgm
# train/non-face/B1_00250.pgm
# train/non-face/B1_00251.pgm
# train/non-face/B1_00252.pgm
# train/non-face/B1_00253.pgm
# train/non-face/B1_00254.pgm
# train/non-face/B1_00255.pgm
# train/non-face/B1_00256.pgm
# train/non-face/B1_00257.pgm
# train/non-face/B1_00258.pgm
# train/non-face/B1_00259.pgm
# train/non-face/B1_00260.pgm
# train/non-face/B1_00261.pgm
# train/non-face/B1_00262.pgm
# train/non-face/B1_00263.pgm
# train/non-face/B1_00264.pgm
# train/non-face/B1_00265.pgm
# train/non-face/B1_00266.pgm
# train/non-face/B1_00267.pgm
# train/non-face/B1_00268.pgm
# train/non-face/B1_00269.pgm
# train/non-face/B1_00270.pgm
# train/non-face/B1_00271.pgm
# train/non-face/B1_00272.pgm
# train/non-face/B1_00273.pgm
# train/non-face/B1_00274.pgm
# train/non-face/B1_00275.pgm
# train/non-face/B1_00276.pgm
# train/non-face/B1_00277.pgm
# train/non-face/B1_00278.pgm
# train/non-face/B1_00279.pgm
# train/non-face/B1_00280.pgm
# train/non-face/B1_00281.pgm
# train/non-face/B1_00282.pgm
# train/non-face/B1_00283.pgm
# train/non-face/B1_00284.pgm
# train/non-face/B1_00285.pgm
# train/non-face/B1_00286.pgm
# train/non-face/B1_00287.pgm
# train/non-face/B1_00288.pgm
# train/non-face/B1_00289.pgm
# train/non-face/B1_00290.pgm
# train/non-face/B1_00291.pgm
# train/non-face/B1_00292.pgm
# train/non-face/B1_00293.pgm
# train/non-face/B1_00294.pgm
# train/non-face/B1_00295.pgm
# train/non-face/B1_00296.pgm
# train/non-face/B1_00297.pgm
# train/non-face/B1_00298.pgm
# train/non-face/B1_00299.pgm
# train/non-face/B1_00300.pgm
# train/non-face/B1_00301.pgm
# train/non-face/B1_00302.pgm
# train/non-face/B1_00303.pgm
# train/non-face/B1_00304.pgm
# train/non-face/B1_00305.pgm
# train/non-face/B1_00306.pgm
# train/non-face/B1_00307.pgm
# train/non-face/B1_00308.pgm
# train/non-face/B1_00309.pgm
# train/non-face/B1_00310.pgm
# train/non-face/B1_00311.pgm
# train/non-face/B1_00312.pgm
# train/non-face/B1_00313.pgm
# train/non-face/B1_00314.pgm
# train/non-face/B1_00315.pgm
# train/non-face/B1_00316.pgm
# train/non-face/B1_00317.pgm
# train/non-face/B1_00318.pgm
# train/non-face/B1_00319.pgm
# train/non-face/B1_00320.pgm
# train/non-face/B1_00321.pgm
# train/non-face/B1_00322.pgm
# train/non-face/B1_00323.pgm
# train/non-face/B1_00324.pgm
# train/non-face/B1_00325.pgm
# train/non-face/B1_00326.pgm
# train/non-face/B1_00327.pgm
# train/non-face/B1_00328.pgm
# train/non-face/B1_00329.pgm
# train/non-face/B1_00330.pgm
# train/non-face/B1_00331.pgm
# train/non-face/B1_00332.pgm
# train/non-face/B1_00333.pgm
# train/non-face/B1_00334.pgm
# train/non-face/B1_00335.pgm
# train/non-face/B1_00336.pgm
# train/non-face/B1_00337.pgm
# train/non-face/B1_00338.pgm
# train/non-face/B1_00339.pgm
# train/non-face/B1_00340.pgm
# train/non-face/B1_00341.pgm
# train/non-face/B1_00342.pgm
# train/non-face/B1_00343.pgm
# train/non-face/B1_00344.pgm
# train/non-face/B1_00345.pgm
# train/non-face/B1_00346.pgm
# train/non-face/B1_00347.pgm
# train/non-face/B1_00348.pgm
# train/non-face/B1_00349.pgm
# train/non-face/B1_00350.pgm
# train/non-face/B1_00351.pgm
# train/non-face/B1_00352.pgm
# train/non-face/B1_00353.pgm
# train/non-face/B1_00354.pgm
# train/non-face/B1_00355.pgm
# train/non-face/B1_00356.pgm
# train/non-face/B1_00357.pgm
# train/non-face/B1_00358.pgm
# train/non-face/B1_00359.pgm
# train/non-face/B1_00360.pgm
# train/non-face/B1_00361.pgm
# train/non-face/B1_00362.pgm
# train/non-face/B1_00363.pgm
# train/non-face/B1_00364.pgm
# train/non-face/B1_00365.pgm
# train/non-face/B1_00366.pgm
# train/non-face/B1_00367.pgm
# train/non-face/B1_00368.pgm
# train/non-face/B1_00369.pgm
# train/non-face/B1_00370.pgm
# train/non-face/B1_00371.pgm
# train/non-face/B1_00372.pgm
# train/non-face/B1_00373.pgm
# train/non-face/B1_00374.pgm
# train/non-face/B1_00375.pgm
# train/non-face/B1_00376.pgm
# train/non-face/B1_00377.pgm
# train/non-face/B1_00378.pgm
# train/non-face/B1_00379.pgm
# train/non-face/B1_00380.pgm
# train/non-face/B1_00381.pgm
# train/non-face/B1_00382.pgm
# train/non-face/B1_00383.pgm
# train/non-face/B1_00384.pgm
# train/non-face/B1_00385.pgm
# train/non-face/B1_00386.pgm
# train/non-face/B1_00387.pgm
# train/non-face/B1_00388.pgm
# train/non-face/B1_00389.pgm
# train/non-face/B1_00390.pgm
# train/non-face/B1_00391.pgm
# train/non-face/B1_00392.pgm
# train/non-face/B1_00393.pgm
# train/non-face/B1_00394.pgm
# train/non-face/B1_00395.pgm
# train/non-face/B1_00396.pgm
# train/non-face/B1_00397.pgm
# train/non-face/B1_00398.pgm
# train/non-face/B1_00399.pgm
# train/non-face/B1_00400.pgm
# train/non-face/B1_00401.pgm
# train/non-face/B1_00402.pgm
# train/non-face/B1_00403.pgm
# train/non-face/B1_00404.pgm
# train/non-face/B1_00405.pgm
# train/non-face/B1_00406.pgm
# train/non-face/B1_00407.pgm
# train/non-face/B1_00408.pgm
# train/non-face/B1_00409.pgm
# train/non-face/B1_00410.pgm
# train/non-face/B1_00411.pgm
# train/non-face/B1_00412.pgm
# train/non-face/B1_00413.pgm
# train/non-face/B1_00414.pgm
# train/non-face/B1_00415.pgm
# train/non-face/B1_00416.pgm
# train/non-face/B1_00417.pgm
# train/non-face/B1_00418.pgm
# train/non-face/B1_00419.pgm
# train/non-face/B1_00420.pgm
# train/non-face/B1_00421.pgm
# train/non-face/B1_00422.pgm
# train/non-face/B1_00423.pgm
# train/non-face/B1_00424.pgm
# train/non-face/B1_00425.pgm
# train/non-face/B1_00426.pgm
# train/non-face/B1_00427.pgm
# train/non-face/B1_00428.pgm
# train/non-face/B1_00429.pgm
# train/non-face/B1_00430.pgm
# train/non-face/B1_00431.pgm
# train/non-face/B1_00432.pgm
# train/non-face/B1_00433.pgm
# train/non-face/B1_00434.pgm
# train/non-face/B1_00435.pgm
# train/non-face/B1_00436.pgm
# train/non-face/B1_00437.pgm
# train/non-face/B1_00438.pgm
# train/non-face/B1_00439.pgm
# train/non-face/B1_00440.pgm
# train/non-face/B1_00441.pgm
# train/non-face/B1_00442.pgm
# train/non-face/B1_00443.pgm
# train/non-face/B1_00444.pgm
# train/non-face/B1_00445.pgm
# train/non-face/B1_00446.pgm
# train/non-face/B1_00447.pgm
# train/non-face/B1_00448.pgm
# train/non-face/B1_00449.pgm
# train/non-face/B1_00450.pgm
# train/non-face/B1_00451.pgm
# train/non-face/B1_00452.pgm
# train/non-face/B1_00453.pgm
# train/non-face/B1_00454.pgm
# train/non-face/B1_00455.pgm
# train/non-face/B1_00456.pgm
# train/non-face/B1_00457.pgm
# train/non-face/B1_00458.pgm
# train/non-face/B1_00459.pgm
# train/non-face/B1_00460.pgm
# train/non-face/B1_00461.pgm
# train/non-face/B1_00462.pgm
# train/non-face/B1_00463.pgm
# train/non-face/B1_00464.pgm
# train/non-face/B1_00465.pgm
# train/non-face/B1_00466.pgm
# train/non-face/B1_00467.pgm
# train/non-face/B1_00468.pgm
# train/non-face/B1_00469.pgm
# train/non-face/B1_00470.pgm
# train/non-face/B1_00471.pgm
# train/non-face/B1_00472.pgm
# train/non-face/B1_00473.pgm
# train/non-face/B1_00474.pgm
# train/non-face/B1_00475.pgm
# train/non-face/B1_00476.pgm
# train/non-face/B1_00477.pgm
# train/non-face/B1_00478.pgm
# train/non-face/B1_00479.pgm
# train/non-face/B1_00480.pgm
# train/non-face/B1_00481.pgm
# train/non-face/B1_00482.pgm
# train/non-face/B1_00483.pgm
# train/non-face/B1_00484.pgm
# train/non-face/B1_00485.pgm
# train/non-face/B1_00486.pgm
# train/non-face/B1_00487.pgm
# train/non-face/B1_00488.pgm
# train/non-face/B1_00489.pgm
# train/non-face/B1_00490.pgm
# train/non-face/B1_00491.pgm
# train/non-face/B1_00492.pgm
# train/non-face/B1_00493.pgm
# train/non-face/B1_00494.pgm
# train/non-face/B1_00495.pgm
# train/non-face/B1_00496.pgm
# train/non-face/B1_00497.pgm
# train/non-face/B1_00498.pgm
# train/non-face/B1_00499.pgm
# train/non-face/B1_00500.pgm
# train/non-face/B1_00501.pgm
# train/non-face/B1_00502.pgm
# train/non-face/B1_00503.pgm
# train/non-face/B1_00504.pgm
# train/non-face/B1_00505.pgm
# train/non-face/B1_00506.pgm
# train/non-face/B1_00507.pgm
# train/non-face/B1_00508.pgm
# train/non-face/B1_00509.pgm
# train/non-face/B1_00510.pgm
# train/non-face/B1_00511.pgm
# train/non-face/B1_00512.pgm
# train/non-face/B1_00513.pgm
# train/non-face/B1_00514.pgm
# train/non-face/B1_00515.pgm
# train/non-face/B1_00516.pgm
# train/non-face/B1_00517.pgm
# train/non-face/B1_00518.pgm
# train/non-face/B1_00519.pgm
# train/non-face/B1_00520.pgm
# train/non-face/B1_00521.pgm
# train/non-face/B1_00522.pgm
# train/non-face/B1_00523.pgm
# train/non-face/B1_00524.pgm
# train/non-face/B1_00525.pgm
# train/non-face/B1_00526.pgm
# train/non-face/B1_00527.pgm
# train/non-face/B1_00528.pgm
# train/non-face/B1_00529.pgm
# train/non-face/B1_00530.pgm
# train/non-face/B1_00531.pgm
# train/non-face/B1_00532.pgm
# train/non-face/B1_00533.pgm
# train/non-face/B1_00534.pgm
# train/non-face/B1_00535.pgm
# train/non-face/B1_00536.pgm
# train/non-face/B1_00537.pgm
# train/non-face/B1_00538.pgm
# train/non-face/B1_00539.pgm
# train/non-face/B1_00540.pgm
# train/non-face/B1_00541.pgm
# train/non-face/B1_00542.pgm
# train/non-face/B1_00543.pgm
# train/non-face/B1_00544.pgm
# train/non-face/B1_00545.pgm
# train/non-face/B1_00546.pgm
# train/non-face/B1_00547.pgm
# train/non-face/B1_00548.pgm
# train/non-face/B1_00549.pgm
# train/non-face/B1_00550.pgm
# train/non-face/B1_00551.pgm
# train/non-face/B1_00552.pgm
# train/non-face/B1_00553.pgm
# train/non-face/B1_00554.pgm
# train/non-face/B1_00555.pgm
# train/non-face/B1_00556.pgm
# train/non-face/B1_00557.pgm
# train/non-face/B1_00558.pgm
# train/non-face/B1_00559.pgm
# train/non-face/B20_01507.pgm
# train/non-face/B20_01508.pgm
# train/non-face/B20_01509.pgm
# train/non-face/B20_01510.pgm
# train/non-face/B20_01511.pgm
# train/non-face/B20_01512.pgm
# train/non-face/B20_01513.pgm
# train/non-face/B20_01514.pgm
# train/non-face/B20_01515.pgm
# train/non-face/B20_01516.pgm
# train/non-face/B20_01517.pgm
# train/non-face/B20_01518.pgm
# train/non-face/B20_01519.pgm
# train/non-face/B20_01520.pgm
# train/non-face/B20_01521.pgm
# train/non-face/B20_01522.pgm
# train/non-face/B20_01523.pgm
# train/non-face/B20_01524.pgm
# train/non-face/B20_01525.pgm
# train/non-face/B20_01526.pgm
# train/non-face/B20_01527.pgm
# train/non-face/B20_01528.pgm
# train/non-face/B20_01529.pgm
# train/non-face/B20_01530.pgm
# train/non-face/B20_01531.pgm
# train/non-face/B20_01532.pgm
# train/non-face/B20_01533.pgm
# train/non-face/B20_01534.pgm
# train/non-face/B20_01535.pgm
# train/non-face/B20_01536.pgm
# train/non-face/B20_01537.pgm
# train/non-face/B20_01538.pgm
# train/non-face/B20_01539.pgm
# train/non-face/B20_01540.pgm
# train/non-face/B20_01541.pgm
# train/non-face/B20_01542.pgm
# train/non-face/B20_01543.pgm
# train/non-face/B20_01544.pgm
# train/non-face/B20_01545.pgm
# train/non-face/B20_01546.pgm
# train/non-face/B20_01547.pgm
# train/non-face/B20_01548.pgm
# train/non-face/B20_01549.pgm
# train/non-face/B20_01550.pgm
# train/non-face/B20_01551.pgm
# train/non-face/B20_01552.pgm
# train/non-face/B20_01553.pgm
# train/non-face/B20_01554.pgm
# train/non-face/B20_01555.pgm
# train/non-face/B20_01556.pgm
# train/non-face/B20_01557.pgm
# train/non-face/B20_01558.pgm
# train/non-face/B20_01559.pgm
# train/non-face/B20_01560.pgm
# train/non-face/B20_01561.pgm
# train/non-face/B20_01562.pgm
# train/non-face/B20_01563.pgm
# train/non-face/B20_01564.pgm
# train/non-face/B20_01565.pgm
# train/non-face/B20_01566.pgm
# train/non-face/B20_01567.pgm
# train/non-face/B20_01568.pgm
# train/non-face/B20_01569.pgm
# train/non-face/B20_01570.pgm
# train/non-face/B20_01571.pgm
# train/non-face/B20_01572.pgm
# train/non-face/B20_01573.pgm
# train/non-face/B20_01574.pgm
# train/non-face/B20_01575.pgm
# train/non-face/B20_01576.pgm
# train/non-face/B20_01577.pgm
# train/non-face/B20_01578.pgm
# train/non-face/B20_01579.pgm
# train/non-face/B20_01580.pgm
# train/non-face/B20_01581.pgm
# train/non-face/B20_01582.pgm
# train/non-face/B20_01583.pgm
# train/non-face/B20_01584.pgm
# train/non-face/B20_01585.pgm
# train/non-face/B20_01586.pgm
# train/non-face/B20_01587.pgm
# train/non-face/B20_01588.pgm
# train/non-face/B20_01589.pgm
# train/non-face/B20_01590.pgm
# train/non-face/B20_01591.pgm
# train/non-face/B20_01592.pgm
# train/non-face/B20_01593.pgm
# train/non-face/B20_01594.pgm
# train/non-face/B20_01595.pgm
# train/non-face/B20_01596.pgm
# train/non-face/B20_01597.pgm
# train/non-face/B20_01598.pgm
# train/non-face/B20_01599.pgm
# train/non-face/B20_01600.pgm
# train/non-face/B20_01601.pgm
# train/non-face/B20_01602.pgm
# train/non-face/B20_01603.pgm
# train/non-face/B20_01604.pgm
# train/non-face/B20_01605.pgm
# train/non-face/B20_01606.pgm
# train/non-face/B20_01607.pgm
# train/non-face/B20_01608.pgm
# train/non-face/B20_01609.pgm
# train/non-face/B20_01610.pgm
# train/non-face/B20_01611.pgm
# train/non-face/B20_01612.pgm
# train/non-face/B20_01613.pgm
# train/non-face/B20_01614.pgm
# train/non-face/B20_01615.pgm
# train/non-face/B20_01616.pgm
# train/non-face/B20_01617.pgm
# train/non-face/B20_01618.pgm
# train/non-face/B20_01619.pgm
# train/non-face/B20_01620.pgm
# train/non-face/B20_01621.pgm
# train/non-face/B20_01622.pgm
# train/non-face/B20_01623.pgm
# train/non-face/B20_01624.pgm
# train/non-face/B20_01625.pgm
# train/non-face/B20_01626.pgm
# train/non-face/B20_01627.pgm
# train/non-face/B20_01628.pgm
# train/non-face/B20_01629.pgm
# train/non-face/B20_01630.pgm
# train/non-face/B20_01631.pgm
# train/non-face/B20_01632.pgm
# train/non-face/B20_01633.pgm
# train/non-face/B20_01634.pgm
# train/non-face/B20_01635.pgm
# train/non-face/B20_01636.pgm
# train/non-face/B20_01637.pgm
# train/non-face/B20_01638.pgm
# train/non-face/B20_01639.pgm
# train/non-face/B20_01640.pgm
# train/non-face/B20_01641.pgm
# train/non-face/B20_01642.pgm
# train/non-face/B20_01643.pgm
# train/non-face/B20_01644.pgm
# train/non-face/B20_01645.pgm
# train/non-face/B20_01646.pgm
# train/non-face/B20_01647.pgm
# train/non-face/B20_01648.pgm
# train/non-face/B20_01649.pgm
# train/non-face/B20_01650.pgm
# train/non-face/B20_01651.pgm
# train/non-face/B20_01652.pgm
# train/non-face/B20_01653.pgm
# train/non-face/B20_01654.pgm
# train/non-face/B20_01655.pgm
# train/non-face/B20_01656.pgm
# train/non-face/B20_01657.pgm
# train/non-face/B20_01658.pgm
# train/non-face/B20_01659.pgm
# train/non-face/B20_01660.pgm
# train/non-face/B20_01661.pgm
# train/non-face/B20_01662.pgm
# train/non-face/B20_01663.pgm
# train/non-face/B20_01664.pgm
# train/non-face/B20_01665.pgm
# train/non-face/B20_01666.pgm
# train/non-face/B20_01667.pgm
# train/non-face/B20_01668.pgm
# train/non-face/B20_01669.pgm
# train/non-face/B20_01670.pgm
# train/non-face/B20_01671.pgm
# train/non-face/B20_01672.pgm
# train/non-face/B20_01673.pgm
# train/non-face/B20_01674.pgm
# train/non-face/B20_01675.pgm
# train/non-face/B20_01676.pgm
# train/non-face/B20_01677.pgm
# train/non-face/B20_01678.pgm
# train/non-face/B20_01679.pgm
# train/non-face/B20_01680.pgm
# train/non-face/B20_01681.pgm
# train/non-face/B20_01682.pgm
# train/non-face/B20_01683.pgm
# train/non-face/B20_01684.pgm
# train/non-face/B20_01685.pgm
# train/non-face/B20_01686.pgm
# train/non-face/B20_01687.pgm
# train/non-face/B20_01688.pgm
# train/non-face/B20_01689.pgm
# train/non-face/B20_01690.pgm
# train/non-face/B20_01691.pgm
# train/non-face/B20_01692.pgm
# train/non-face/B20_01693.pgm
# train/non-face/B20_01694.pgm
# train/non-face/B20_01695.pgm
# train/non-face/B20_01696.pgm
# train/non-face/B20_01697.pgm
# train/non-face/B20_01698.pgm
# train/non-face/B20_01699.pgm
# train/non-face/B20_01700.pgm
# train/non-face/B20_01701.pgm
# train/non-face/B20_01702.pgm
# train/non-face/B20_01703.pgm
# train/non-face/B20_01704.pgm
# train/non-face/B20_01705.pgm
# train/non-face/B20_01706.pgm
# train/non-face/B20_01707.pgm
# train/non-face/B20_01708.pgm
# train/non-face/B20_01709.pgm
# train/non-face/B20_01710.pgm
# train/non-face/B20_01711.pgm
# train/non-face/B20_01712.pgm
# train/non-face/B20_01713.pgm
# train/non-face/B20_01714.pgm
# train/non-face/B20_01715.pgm
# train/non-face/B20_01716.pgm
# train/non-face/B20_01717.pgm
# train/non-face/B20_01718.pgm
# train/non-face/B20_01719.pgm
# train/non-face/B20_01720.pgm
# train/non-face/B20_01721.pgm
# train/non-face/B20_01722.pgm
# train/non-face/B20_01723.pgm
# train/non-face/B20_01724.pgm
# train/non-face/B20_01725.pgm
# train/non-face/B20_01726.pgm
# train/non-face/B20_01727.pgm
# train/non-face/B20_01728.pgm
# train/non-face/B20_01729.pgm
# train/non-face/B20_01730.pgm
# train/non-face/B20_01731.pgm
# train/non-face/B20_01732.pgm
# train/non-face/B20_01733.pgm
# train/non-face/B20_01734.pgm
# train/non-face/B20_01735.pgm
# train/non-face/B20_01736.pgm
# train/non-face/B20_01737.pgm
# train/non-face/B20_01738.pgm
# train/non-face/B20_01739.pgm
# train/non-face/B20_01740.pgm
# train/non-face/B20_01741.pgm
# train/non-face/B20_01742.pgm
# train/non-face/B20_01743.pgm
# train/non-face/B20_01744.pgm
# train/non-face/B20_01745.pgm
# train/non-face/B20_01746.pgm
# train/non-face/B20_01747.pgm
# train/non-face/B20_01748.pgm
# train/non-face/B20_01749.pgm
# train/non-face/B20_01750.pgm
# train/non-face/B20_01751.pgm
# train/non-face/B20_01752.pgm
# train/non-face/B20_01753.pgm
# train/non-face/B20_01754.pgm
# train/non-face/B20_01755.pgm
# train/non-face/B20_01756.pgm
# train/non-face/B20_01757.pgm
# train/non-face/B20_01758.pgm
# train/non-face/B20_01759.pgm
# train/non-face/B20_01760.pgm
# train/non-face/B20_01761.pgm
# train/non-face/B20_01762.pgm
# train/non-face/B20_01763.pgm
# train/non-face/B20_01764.pgm
# train/non-face/B20_01765.pgm
# train/non-face/B20_01766.pgm
# train/non-face/B20_01767.pgm
# train/non-face/B20_01768.pgm
# train/non-face/B20_01769.pgm
# train/non-face/B20_01770.pgm
# train/non-face/B20_01771.pgm
# train/non-face/B20_01772.pgm
# train/non-face/B20_01773.pgm
# train/non-face/B20_01774.pgm
# train/non-face/B20_01775.pgm
# train/non-face/B20_01776.pgm
# train/non-face/B20_01777.pgm
# train/non-face/B20_01778.pgm
# train/non-face/B20_01779.pgm
# train/non-face/B20_01780.pgm
# train/non-face/B20_01781.pgm
# train/non-face/B20_01782.pgm
# train/non-face/B20_01783.pgm
# train/non-face/B20_01784.pgm
# train/non-face/B20_01785.pgm
# train/non-face/B20_01786.pgm
# train/non-face/B20_01787.pgm
# train/non-face/B20_01788.pgm
# train/non-face/B20_01789.pgm
# train/non-face/B20_01790.pgm
# train/non-face/B20_01791.pgm
# train/non-face/B20_01792.pgm
# train/non-face/B20_01793.pgm
# train/non-face/B20_01794.pgm
# train/non-face/B20_01795.pgm
# train/non-face/B20_01796.pgm
# train/non-face/B20_01797.pgm
# train/non-face/B20_01798.pgm
# train/non-face/B20_01799.pgm
# train/non-face/B20_01800.pgm
# train/non-face/B20_01801.pgm
# train/non-face/B20_01802.pgm
# train/non-face/B20_01803.pgm
# train/non-face/B20_01804.pgm
# train/non-face/B20_01805.pgm
# train/non-face/B20_01806.pgm
# train/non-face/B20_01807.pgm
# train/non-face/B20_01808.pgm
# train/non-face/B20_01809.pgm
# train/non-face/B20_01810.pgm
# train/non-face/B20_01811.pgm
# train/non-face/B20_01812.pgm
# train/non-face/B20_01813.pgm
# train/non-face/B20_01814.pgm
# train/non-face/B20_01815.pgm
# train/non-face/B20_01816.pgm
# train/non-face/B20_01817.pgm
# train/non-face/B20_01818.pgm
# train/non-face/B20_01819.pgm
# train/non-face/B20_01820.pgm
# train/non-face/B20_01821.pgm
# train/non-face/B20_01822.pgm
# train/non-face/B20_01823.pgm
# train/non-face/B20_01824.pgm
# train/non-face/B20_01825.pgm
# train/non-face/B20_01826.pgm
# train/non-face/B20_01827.pgm
# train/non-face/B20_01828.pgm
# train/non-face/B20_01829.pgm
# train/non-face/B20_01830.pgm
# train/non-face/B20_01831.pgm
# train/non-face/B20_01832.pgm
# train/non-face/B20_01833.pgm
# train/non-face/B20_01834.pgm
# train/non-face/B20_01835.pgm
# train/non-face/B20_01836.pgm
# train/non-face/B20_01837.pgm
# train/non-face/B20_01838.pgm
# train/non-face/B20_01839.pgm
# train/non-face/B20_01840.pgm
# train/non-face/B20_01841.pgm
# train/non-face/B20_01842.pgm
# train/non-face/B20_01843.pgm
# train/non-face/B20_01844.pgm
# train/non-face/B20_01845.pgm
# train/non-face/B20_01846.pgm
# train/non-face/B20_01847.pgm
# train/non-face/B20_01848.pgm
# train/non-face/B20_01849.pgm
# train/non-face/B20_01850.pgm
# train/non-face/B20_01851.pgm
# train/non-face/B20_01852.pgm
# train/non-face/B20_01853.pgm
# train/non-face/B20_01854.pgm
# train/non-face/B20_01855.pgm
# train/non-face/B20_01856.pgm
# train/non-face/B20_01857.pgm
# train/non-face/B20_01858.pgm
# train/non-face/B20_01859.pgm
# train/non-face/B20_01860.pgm
# train/non-face/B20_01861.pgm
# train/non-face/B20_01862.pgm
# train/non-face/B20_01863.pgm
# train/non-face/B20_01864.pgm
# train/non-face/B20_01865.pgm
# train/non-face/B20_01866.pgm
# train/non-face/B20_01867.pgm
# train/non-face/B20_01868.pgm
# train/non-face/B20_01869.pgm
# train/non-face/B20_01870.pgm
# train/non-face/B20_01871.pgm
# train/non-face/B20_01872.pgm
# train/non-face/B20_01873.pgm
# train/non-face/B20_01874.pgm
# train/non-face/B20_01875.pgm
# train/non-face/B20_01876.pgm
# train/non-face/B20_01877.pgm
# train/non-face/B20_01878.pgm
# train/non-face/B20_01879.pgm
# train/non-face/B20_01880.pgm
# train/non-face/B20_01881.pgm
# train/non-face/B20_01882.pgm
# train/non-face/B20_01883.pgm
# train/non-face/B20_01884.pgm
# train/non-face/B20_01885.pgm
# train/non-face/B20_01886.pgm
# train/non-face/B20_01887.pgm
# train/non-face/B20_01888.pgm
# train/non-face/B20_01889.pgm
# train/non-face/B20_01890.pgm
# train/non-face/B20_01891.pgm
# train/non-face/B20_01892.pgm
# train/non-face/B20_01893.pgm
# train/non-face/B20_01894.pgm
# train/non-face/B20_01895.pgm
# train/non-face/B20_01896.pgm
# train/non-face/B20_01897.pgm
# train/non-face/B20_01898.pgm
# train/non-face/B20_01899.pgm
# train/non-face/B20_01900.pgm
# train/non-face/B20_01901.pgm
# train/non-face/B20_01902.pgm
# train/non-face/B20_01903.pgm
# train/non-face/B20_01904.pgm
# train/non-face/B20_01905.pgm
# train/non-face/B20_01906.pgm
# train/non-face/B20_01907.pgm
# train/non-face/B20_01908.pgm
# train/non-face/B20_01909.pgm
# train/non-face/B20_01910.pgm
# train/non-face/B20_01911.pgm
# train/non-face/B20_01912.pgm
# train/non-face/B20_01913.pgm
# train/non-face/B20_01914.pgm
# train/non-face/B20_01915.pgm
# train/non-face/B20_01916.pgm
# train/non-face/B20_01917.pgm
# train/non-face/B20_01918.pgm
# train/non-face/B20_01919.pgm
# train/non-face/B20_01920.pgm
# train/non-face/B20_01921.pgm
# train/non-face/B20_01922.pgm
# train/non-face/B20_01923.pgm
# train/non-face/B20_01924.pgm
# train/non-face/B20_01925.pgm
# train/non-face/B20_01926.pgm
# train/non-face/B20_01927.pgm
# train/non-face/B20_01928.pgm
# train/non-face/B20_01929.pgm
# train/non-face/B20_01930.pgm
# train/non-face/B20_01931.pgm
# train/non-face/B20_01932.pgm
# train/non-face/B20_01933.pgm
# train/non-face/B20_01934.pgm
# train/non-face/B20_01935.pgm
# train/non-face/B20_01936.pgm
# train/non-face/B20_01937.pgm
# train/non-face/B20_01938.pgm
# train/non-face/B20_01939.pgm
# train/non-face/B20_01940.pgm
# train/non-face/B20_01941.pgm
# train/non-face/B20_01942.pgm
# train/non-face/B20_01943.pgm
# train/non-face/B20_01944.pgm
# train/non-face/B20_01945.pgm
# train/non-face/B20_01946.pgm
# train/non-face/B20_01947.pgm
# train/non-face/B20_01948.pgm
# train/non-face/B20_01949.pgm
# train/non-face/B20_01950.pgm
# train/non-face/B20_01951.pgm
# train/non-face/B20_01952.pgm
# train/non-face/B20_01953.pgm
# train/non-face/B20_01954.pgm
# train/non-face/B20_01955.pgm
# train/non-face/B20_01956.pgm
# train/non-face/B20_01957.pgm
# train/non-face/B20_01958.pgm
# train/non-face/B20_01959.pgm
# train/non-face/B20_01960.pgm
# train/non-face/B20_01961.pgm
# train/non-face/B20_01962.pgm
# train/non-face/B20_01963.pgm
# train/non-face/B20_01964.pgm
# train/non-face/B20_01965.pgm
# train/non-face/B20_01966.pgm
# train/non-face/B20_01967.pgm
# train/non-face/B20_01968.pgm
# train/non-face/B20_01969.pgm
# train/non-face/B20_01970.pgm
# train/non-face/B20_01971.pgm
# train/non-face/B20_01972.pgm
# train/non-face/B20_01973.pgm
# train/non-face/B20_01974.pgm
# train/non-face/B20_01975.pgm
# train/non-face/B20_01976.pgm
# train/non-face/B20_01977.pgm
# train/non-face/B20_01978.pgm
# train/non-face/B20_01979.pgm
# train/non-face/B20_01980.pgm
# train/non-face/B20_01981.pgm
# train/non-face/B20_01982.pgm
# train/non-face/B20_01983.pgm
# train/non-face/B20_01984.pgm
# train/non-face/B20_01985.pgm
# train/non-face/B20_01986.pgm
# train/non-face/B20_01987.pgm
# train/non-face/B20_01988.pgm
# train/non-face/B20_01989.pgm
# train/non-face/B20_01990.pgm
# train/non-face/B20_01991.pgm
# train/non-face/B20_01992.pgm
# train/non-face/B20_01993.pgm
# train/non-face/B20_01994.pgm
# train/non-face/B20_01995.pgm
# train/non-face/B20_01996.pgm
# train/non-face/B20_01997.pgm
# train/non-face/B20_01998.pgm
# train/non-face/B20_01999.pgm
# train/non-face/B20_02000.pgm
# train/non-face/B20_02001.pgm
# train/non-face/B20_02002.pgm
# train/non-face/B20_02003.pgm
# train/non-face/B20_02004.pgm
# train/non-face/B20_02005.pgm
# train/non-face/B20_02006.pgm
# train/non-face/B20_02007.pgm
# train/non-face/B20_02008.pgm
# train/non-face/B20_02009.pgm
# train/non-face/B20_02010.pgm
# train/non-face/B20_02011.pgm
# train/non-face/B20_02012.pgm
# train/non-face/B20_02013.pgm
# train/non-face/B20_02014.pgm
# train/non-face/B20_02015.pgm
# train/non-face/B20_02016.pgm
# train/non-face/B20_02017.pgm
# train/non-face/B20_02018.pgm
# train/non-face/B20_02019.pgm
# train/non-face/B20_02020.pgm
# train/non-face/B20_02021.pgm
# train/non-face/B20_02022.pgm
# train/non-face/B20_02023.pgm
# train/non-face/B20_02024.pgm
# train/non-face/B20_02025.pgm
# train/non-face/B20_02026.pgm
# train/non-face/B20_02027.pgm
# train/non-face/B20_02028.pgm
# train/non-face/B20_02029.pgm
# train/non-face/B20_02030.pgm
# train/non-face/B20_02031.pgm
# train/non-face/B20_02032.pgm
# train/non-face/B20_02033.pgm
# train/non-face/B20_02034.pgm
# train/non-face/B20_02035.pgm
# train/non-face/B20_02036.pgm
# train/non-face/B20_02037.pgm
# train/non-face/B20_02038.pgm
# train/non-face/B20_02039.pgm
# train/non-face/B20_02040.pgm
# train/non-face/B20_02041.pgm
# train/non-face/B20_02042.pgm
# train/non-face/B20_02043.pgm
# train/non-face/B20_02044.pgm
# train/non-face/B20_02045.pgm
# train/non-face/B20_02046.pgm
# train/non-face/B20_02047.pgm
# train/non-face/B20_02048.pgm
# train/non-face/B20_02049.pgm
# train/non-face/B20_02050.pgm
# train/non-face/B20_02051.pgm
# train/non-face/B20_02052.pgm
# train/non-face/B20_02053.pgm
# train/non-face/B20_02054.pgm
# train/non-face/B20_02055.pgm
# train/non-face/B20_02056.pgm
# train/non-face/B20_02057.pgm
# train/non-face/B20_02058.pgm
# train/non-face/B20_02059.pgm
# train/non-face/B20_02060.pgm
# train/non-face/B20_02061.pgm
# train/non-face/B20_02062.pgm
# train/non-face/B20_02063.pgm
# train/non-face/B20_02064.pgm
# train/non-face/B20_02065.pgm
# train/non-face/B20_02066.pgm
# train/non-face/B20_02067.pgm
# train/non-face/B20_02068.pgm
# train/non-face/B20_02069.pgm
# train/non-face/B20_02070.pgm
# train/non-face/B20_02071.pgm
# train/non-face/B20_02072.pgm
# train/non-face/B20_02073.pgm
# train/non-face/B20_02074.pgm
# train/non-face/B20_02075.pgm
# train/non-face/B20_02076.pgm
# train/non-face/B20_02077.pgm
# train/non-face/B20_02078.pgm
# train/non-face/B20_02079.pgm
# train/non-face/B20_02080.pgm
# train/non-face/B20_02081.pgm
# train/non-face/B20_02082.pgm
# train/non-face/B20_02083.pgm
# train/non-face/B20_02084.pgm
# train/non-face/B20_02085.pgm
# train/non-face/B20_02086.pgm
# train/non-face/B20_02087.pgm
# train/non-face/B20_02088.pgm
# train/non-face/B20_02089.pgm
# train/non-face/B20_02090.pgm
# train/non-face/B20_02091.pgm
# train/non-face/B20_02092.pgm
# train/non-face/B20_02093.pgm
# train/non-face/B20_02094.pgm
# train/non-face/B20_02095.pgm
# train/non-face/B20_02096.pgm
# train/non-face/B20_02097.pgm
# train/non-face/B20_02098.pgm
# train/non-face/B20_02099.pgm
# train/non-face/B20_02100.pgm
# train/non-face/B20_02101.pgm
# train/non-face/B20_02102.pgm
# train/non-face/B20_02103.pgm
# train/non-face/B20_02104.pgm
# train/non-face/B20_02105.pgm
# train/non-face/B20_02106.pgm
# train/non-face/B20_02107.pgm
# train/non-face/B20_02108.pgm
# train/non-face/B20_02109.pgm
# train/non-face/B20_02110.pgm
# train/non-face/B20_02111.pgm
# train/non-face/B20_02112.pgm
# train/non-face/B20_02113.pgm
# train/non-face/B20_02114.pgm
# train/non-face/B20_02115.pgm
# train/non-face/B20_02116.pgm
# train/non-face/B20_02117.pgm
# train/non-face/B20_02118.pgm
# train/non-face/B20_02119.pgm
# train/non-face/B20_02120.pgm
# train/non-face/B20_02121.pgm
# train/non-face/B20_02122.pgm
# train/non-face/B20_02123.pgm
# train/non-face/B20_02124.pgm
# train/non-face/B20_02125.pgm
# train/non-face/B20_02126.pgm
# train/non-face/B20_02127.pgm
# train/non-face/B20_02128.pgm
# train/non-face/B20_02129.pgm
# train/non-face/B20_02130.pgm
# train/non-face/B20_02131.pgm
# train/non-face/B20_02132.pgm
# train/non-face/B20_02133.pgm
# train/non-face/B20_02134.pgm
# train/non-face/B20_02135.pgm
# train/non-face/B20_02136.pgm
# train/non-face/B20_02137.pgm
# train/non-face/B20_02138.pgm
# train/non-face/B20_02139.pgm
# train/non-face/B20_02140.pgm
# train/non-face/B20_02141.pgm
# train/non-face/B20_02142.pgm
# train/non-face/B20_02143.pgm
# train/non-face/B20_02144.pgm
# train/non-face/B20_02145.pgm
# train/non-face/B20_02146.pgm
# train/non-face/B20_02147.pgm
# train/non-face/B20_02148.pgm
# train/non-face/B20_02149.pgm
# train/non-face/B20_02150.pgm
# train/non-face/B20_02151.pgm
# train/non-face/B20_02152.pgm
# train/non-face/B20_02153.pgm
# train/non-face/B20_02154.pgm
# train/non-face/B20_02155.pgm
# train/non-face/B20_02156.pgm
# train/non-face/B20_02157.pgm
# train/non-face/B20_02158.pgm
# train/non-face/B20_02159.pgm
# train/non-face/B20_02160.pgm
# train/non-face/B20_02161.pgm
# train/non-face/B20_02162.pgm
# train/non-face/B20_02163.pgm
# train/non-face/B20_02164.pgm
# train/non-face/B20_02165.pgm
# train/non-face/B20_02166.pgm
# train/non-face/B20_02167.pgm
# train/non-face/B20_02168.pgm
# train/non-face/B20_02169.pgm
# train/non-face/B20_02170.pgm
# train/non-face/B20_02171.pgm
# train/non-face/B20_02172.pgm
# train/non-face/B20_02173.pgm
# train/non-face/B20_02174.pgm
# train/non-face/B20_02175.pgm
# train/non-face/B20_02176.pgm
# train/non-face/B20_02177.pgm
# train/non-face/B20_02178.pgm
# train/non-face/B20_02179.pgm
# train/non-face/B20_02180.pgm
# train/non-face/B20_02181.pgm
# train/non-face/B20_02182.pgm
# train/non-face/B20_02183.pgm
# train/non-face/B20_02184.pgm
# train/non-face/B20_02185.pgm
# train/non-face/B20_02186.pgm
# train/non-face/B20_02187.pgm
# train/non-face/B20_02188.pgm
# train/non-face/B20_02189.pgm
# train/non-face/B20_02190.pgm
# train/non-face/B20_02191.pgm
# train/non-face/B20_02192.pgm
# train/non-face/B20_02193.pgm
# train/non-face/B20_02194.pgm
# train/non-face/B20_02195.pgm
# train/non-face/B20_02196.pgm
# train/non-face/B20_02197.pgm
# train/non-face/B20_02198.pgm
# train/non-face/B20_02199.pgm
# train/non-face/B20_02200.pgm
# train/non-face/B20_02201.pgm
# train/non-face/B20_02202.pgm
# train/non-face/B20_02203.pgm
# train/non-face/B20_02204.pgm
# train/non-face/B20_02205.pgm
# train/non-face/B20_02206.pgm
# train/non-face/B20_02207.pgm
# train/non-face/B20_02208.pgm
# train/non-face/B20_02209.pgm
# train/non-face/B20_02210.pgm
# train/non-face/B20_02211.pgm
# train/non-face/B20_02212.pgm
# train/non-face/B20_02213.pgm
# train/non-face/B20_02214.pgm
# train/non-face/B20_02215.pgm
# train/non-face/B20_02216.pgm
# train/non-face/B20_02217.pgm
# train/non-face/B20_02218.pgm
# train/non-face/B20_02219.pgm
# train/non-face/B20_02220.pgm
# train/non-face/B20_02221.pgm
# train/non-face/B20_02222.pgm
# train/non-face/B20_02223.pgm
# train/non-face/B20_02224.pgm
# train/non-face/B20_02225.pgm
# train/non-face/B20_02226.pgm
# train/non-face/B20_02227.pgm
# train/non-face/B20_02228.pgm
# train/non-face/B20_02229.pgm
# train/non-face/B20_02230.pgm
# ...
# train/non-face/geyser27_79.pgm
# train/non-face/geyser27_8.pgm
# train/non-face/geyser27_80.pgm
# train/non-face/geyser27_81.pgm
# train/non-face/geyser27_82.pgm
# train/non-face/geyser27_83.pgm
# train/non-face/geyser27_84.pgm
# train/non-face/geyser27_85.pgm
# train/non-face/geyser27_86.pgm
# train/non-face/geyser27_87.pgm
# train/non-face/geyser27_88.pgm
# train/non-face/geyser27_89.pgm
# train/non-face/geyser27_9.pgm
# train/non-face/geyser27_90.pgm
# train/non-face/geyser27_91.pgm
# train/non-face/geyser27_92.pgm
# train/non-face/geyser27_93.pgm
# train/non-face/geyser27_94.pgm
# train/non-face/geyser27_95.pgm
# train/non-face/geyser27_96.pgm
# train/non-face/geyser27_97.pgm
# train/non-face/geyser27_98.pgm
# train/non-face/geyser27_99.pgm
# train/non-face/goldwater67_0.pgm
# train/non-face/goldwater67_1.pgm
# train/non-face/goldwater67_10.pgm
# train/non-face/goldwater67_100.pgm
# train/non-face/goldwater67_101.pgm
# train/non-face/goldwater67_102.pgm
# train/non-face/goldwater67_103.pgm
# train/non-face/goldwater67_104.pgm
# train/non-face/goldwater67_105.pgm
# train/non-face/goldwater67_106.pgm
# train/non-face/goldwater67_107.pgm
# train/non-face/goldwater67_108.pgm
# train/non-face/goldwater67_109.pgm
# train/non-face/goldwater67_11.pgm
# train/non-face/goldwater67_110.pgm
# train/non-face/goldwater67_111.pgm
# train/non-face/goldwater67_112.pgm
# train/non-face/goldwater67_113.pgm
# train/non-face/goldwater67_114.pgm
# train/non-face/goldwater67_115.pgm
# train/non-face/goldwater67_116.pgm
# train/non-face/goldwater67_117.pgm
# train/non-face/goldwater67_118.pgm
# train/non-face/goldwater67_119.pgm
# train/non-face/goldwater67_12.pgm
# train/non-face/goldwater67_120.pgm
# train/non-face/goldwater67_121.pgm
# train/non-face/goldwater67_122.pgm
# train/non-face/goldwater67_123.pgm
# train/non-face/goldwater67_124.pgm
# train/non-face/goldwater67_125.pgm
# train/non-face/goldwater67_126.pgm
# train/non-face/goldwater67_127.pgm
# train/non-face/goldwater67_128.pgm
# train/non-face/goldwater67_129.pgm
# train/non-face/goldwater67_13.pgm
# train/non-face/goldwater67_130.pgm
# train/non-face/goldwater67_131.pgm
# train/non-face/goldwater67_132.pgm
# train/non-face/goldwater67_133.pgm
# train/non-face/goldwater67_134.pgm
# train/non-face/goldwater67_135.pgm
# train/non-face/goldwater67_136.pgm
# train/non-face/goldwater67_137.pgm
# train/non-face/goldwater67_138.pgm
# train/non-face/goldwater67_139.pgm
# train/non-face/goldwater67_14.pgm
# train/non-face/goldwater67_140.pgm
# train/non-face/goldwater67_141.pgm
# train/non-face/goldwater67_142.pgm
# train/non-face/goldwater67_143.pgm
# train/non-face/goldwater67_144.pgm
# train/non-face/goldwater67_145.pgm
# train/non-face/goldwater67_146.pgm
# train/non-face/goldwater67_147.pgm
# train/non-face/goldwater67_148.pgm
# train/non-face/goldwater67_149.pgm
# train/non-face/goldwater67_15.pgm
# train/non-face/goldwater67_150.pgm
# train/non-face/goldwater67_151.pgm
# train/non-face/goldwater67_152.pgm
# train/non-face/goldwater67_153.pgm
# train/non-face/goldwater67_154.pgm
# train/non-face/goldwater67_155.pgm
# train/non-face/goldwater67_156.pgm
# train/non-face/goldwater67_157.pgm
# train/non-face/goldwater67_158.pgm
# train/non-face/goldwater67_159.pgm
# train/non-face/goldwater67_16.pgm
# train/non-face/goldwater67_160.pgm
# train/non-face/goldwater67_161.pgm
# train/non-face/goldwater67_162.pgm
# train/non-face/goldwater67_163.pgm
# train/non-face/goldwater67_164.pgm
# train/non-face/goldwater67_165.pgm
# train/non-face/goldwater67_166.pgm
# train/non-face/goldwater67_167.pgm
# train/non-face/goldwater67_168.pgm
# train/non-face/goldwater67_169.pgm
# train/non-face/goldwater67_17.pgm
# train/non-face/goldwater67_170.pgm
# train/non-face/goldwater67_171.pgm
# train/non-face/goldwater67_172.pgm
# train/non-face/goldwater67_173.pgm
# train/non-face/goldwater67_174.pgm
# train/non-face/goldwater67_175.pgm
# train/non-face/goldwater67_176.pgm
# train/non-face/goldwater67_177.pgm
# train/non-face/goldwater67_178.pgm
# train/non-face/goldwater67_179.pgm
# train/non-face/goldwater67_18.pgm
# train/non-face/goldwater67_180.pgm
# train/non-face/goldwater67_181.pgm
# train/non-face/goldwater67_182.pgm
# train/non-face/goldwater67_183.pgm
# train/non-face/goldwater67_184.pgm
# train/non-face/goldwater67_185.pgm
# train/non-face/goldwater67_186.pgm
# train/non-face/goldwater67_187.pgm
# train/non-face/goldwater67_188.pgm
# train/non-face/goldwater67_189.pgm
# train/non-face/goldwater67_19.pgm
# train/non-face/goldwater67_190.pgm
# train/non-face/goldwater67_191.pgm
# train/non-face/goldwater67_192.pgm
# train/non-face/goldwater67_193.pgm
# train/non-face/goldwater67_194.pgm
# train/non-face/goldwater67_195.pgm
# train/non-face/goldwater67_196.pgm
# train/non-face/goldwater67_197.pgm
# train/non-face/goldwater67_198.pgm
# train/non-face/goldwater67_199.pgm
# train/non-face/goldwater67_2.pgm
# train/non-face/goldwater67_20.pgm
# train/non-face/goldwater67_200.pgm
# train/non-face/goldwater67_201.pgm
# train/non-face/goldwater67_202.pgm
# train/non-face/goldwater67_203.pgm
# train/non-face/goldwater67_204.pgm
# train/non-face/goldwater67_205.pgm
# train/non-face/goldwater67_206.pgm
# train/non-face/goldwater67_207.pgm
# train/non-face/goldwater67_208.pgm
# train/non-face/goldwater67_209.pgm
# train/non-face/goldwater67_21.pgm
# train/non-face/goldwater67_210.pgm
# train/non-face/goldwater67_211.pgm
# train/non-face/goldwater67_212.pgm
# train/non-face/goldwater67_213.pgm
# train/non-face/goldwater67_214.pgm
# train/non-face/goldwater67_215.pgm
# train/non-face/goldwater67_216.pgm
# train/non-face/goldwater67_217.pgm
# train/non-face/goldwater67_218.pgm
# train/non-face/goldwater67_219.pgm
# train/non-face/goldwater67_22.pgm
# train/non-face/goldwater67_220.pgm
# train/non-face/goldwater67_221.pgm
# train/non-face/goldwater67_222.pgm
# train/non-face/goldwater67_223.pgm
# train/non-face/goldwater67_224.pgm
# train/non-face/goldwater67_225.pgm
# train/non-face/graves111_0.pgm
# train/non-face/goldwater67_226.pgm
# train/non-face/goldwater67_227.pgm
# train/non-face/goldwater67_23.pgm
# train/non-face/goldwater67_24.pgm
# train/non-face/goldwater67_25.pgm
# train/non-face/goldwater67_26.pgm
# train/non-face/goldwater67_27.pgm
# train/non-face/goldwater67_28.pgm
# train/non-face/goldwater67_29.pgm
# train/non-face/goldwater67_3.pgm
# train/non-face/goldwater67_30.pgm
# train/non-face/goldwater67_31.pgm
# train/non-face/goldwater67_32.pgm
# train/non-face/goldwater67_33.pgm
# train/non-face/goldwater67_34.pgm
# train/non-face/goldwater67_35.pgm
# train/non-face/goldwater67_36.pgm
# train/non-face/goldwater67_37.pgm
# train/non-face/goldwater67_38.pgm
# train/non-face/goldwater67_39.pgm
# train/non-face/goldwater67_4.pgm
# train/non-face/goldwater67_40.pgm
# train/non-face/goldwater67_41.pgm
# train/non-face/goldwater67_42.pgm
# train/non-face/goldwater67_43.pgm
# train/non-face/goldwater67_44.pgm
# train/non-face/goldwater67_45.pgm
# train/non-face/goldwater67_46.pgm
# train/non-face/goldwater67_47.pgm
# train/non-face/goldwater67_48.pgm
# train/non-face/goldwater67_49.pgm
# train/non-face/goldwater67_5.pgm
# train/non-face/goldwater67_50.pgm
# train/non-face/goldwater67_51.pgm
# train/non-face/goldwater67_52.pgm
# train/non-face/goldwater67_53.pgm
# train/non-face/goldwater67_54.pgm
# train/non-face/goldwater67_55.pgm
# train/non-face/goldwater67_56.pgm
# train/non-face/goldwater67_57.pgm
# train/non-face/goldwater67_58.pgm
# train/non-face/goldwater67_59.pgm
# train/non-face/goldwater67_6.pgm
# train/non-face/goldwater67_60.pgm
# train/non-face/goldwater67_61.pgm
# train/non-face/goldwater67_62.pgm
# train/non-face/goldwater67_63.pgm
# train/non-face/goldwater67_64.pgm
# train/non-face/goldwater67_65.pgm
# train/non-face/goldwater67_66.pgm
# train/non-face/goldwater67_67.pgm
# train/non-face/goldwater67_68.pgm
# train/non-face/goldwater67_69.pgm
# train/non-face/goldwater67_7.pgm
# train/non-face/goldwater67_70.pgm
# train/non-face/goldwater67_71.pgm
# train/non-face/goldwater67_72.pgm
# train/non-face/goldwater67_73.pgm
# train/non-face/goldwater67_74.pgm
# train/non-face/goldwater67_75.pgm
# train/non-face/goldwater67_76.pgm
# train/non-face/goldwater67_77.pgm
# train/non-face/goldwater67_78.pgm
# train/non-face/goldwater67_79.pgm
# train/non-face/goldwater67_8.pgm
# train/non-face/goldwater67_80.pgm
# train/non-face/goldwater67_81.pgm
# train/non-face/goldwater67_82.pgm
# train/non-face/goldwater67_83.pgm
# train/non-face/goldwater67_84.pgm
# train/non-face/goldwater67_85.pgm
# train/non-face/goldwater67_86.pgm
# train/non-face/goldwater67_87.pgm
# train/non-face/goldwater67_88.pgm
# train/non-face/goldwater67_89.pgm
# train/non-face/goldwater67_9.pgm
# train/non-face/goldwater67_90.pgm
# train/non-face/goldwater67_91.pgm
# train/non-face/goldwater67_92.pgm
# train/non-face/goldwater67_93.pgm
# train/non-face/goldwater67_94.pgm
# train/non-face/goldwater67_95.pgm
# train/non-face/goldwater67_96.pgm
# train/non-face/goldwater67_97.pgm
# train/non-face/goldwater67_98.pgm
# train/non-face/goldwater67_99.pgm
# train/non-face/graves111_1.pgm
# train/non-face/graves111_10.pgm
# train/non-face/graves111_100.pgm
# train/non-face/graves111_101.pgm
# train/non-face/graves111_102.pgm
# train/non-face/graves111_103.pgm
# train/non-face/graves111_104.pgm
# train/non-face/graves111_105.pgm
# train/non-face/graves111_106.pgm
# train/non-face/graves111_107.pgm
# train/non-face/graves111_108.pgm
# train/non-face/graves111_109.pgm
# train/non-face/graves111_11.pgm
# train/non-face/graves111_110.pgm
# train/non-face/graves111_111.pgm
# train/non-face/graves111_112.pgm
# train/non-face/graves111_113.pgm
# train/non-face/graves111_114.pgm
# train/non-face/graves111_115.pgm
# train/non-face/graves111_116.pgm
# train/non-face/graves111_117.pgm
# train/non-face/graves111_118.pgm
# train/non-face/graves111_119.pgm
# train/non-face/graves111_12.pgm
# train/non-face/graves111_120.pgm
# train/non-face/graves111_121.pgm
# train/non-face/graves111_122.pgm
# train/non-face/graves111_123.pgm
# train/non-face/graves111_124.pgm
# train/non-face/graves111_125.pgm
# train/non-face/graves111_126.pgm
# train/non-face/graves111_127.pgm
# train/non-face/graves111_128.pgm
# train/non-face/graves111_129.pgm
# train/non-face/graves111_13.pgm
# train/non-face/graves111_130.pgm
# train/non-face/graves111_131.pgm
# train/non-face/graves111_132.pgm
# train/non-face/graves111_133.pgm
# train/non-face/graves111_134.pgm
# train/non-face/graves111_135.pgm
# train/non-face/graves111_136.pgm
# train/non-face/graves111_137.pgm
# train/non-face/graves111_138.pgm
# train/non-face/graves111_139.pgm
# train/non-face/graves111_14.pgm
# train/non-face/graves111_140.pgm
# train/non-face/graves111_141.pgm
# train/non-face/graves111_142.pgm
# train/non-face/graves111_143.pgm
# train/non-face/graves111_144.pgm
# train/non-face/graves111_145.pgm
# train/non-face/graves111_146.pgm
# train/non-face/graves111_147.pgm
# train/non-face/graves111_148.pgm
# train/non-face/graves111_149.pgm
# train/non-face/graves111_15.pgm
# train/non-face/graves111_150.pgm
# train/non-face/graves111_151.pgm
# train/non-face/graves111_152.pgm
# train/non-face/graves111_153.pgm
# train/non-face/graves111_154.pgm
# train/non-face/graves111_155.pgm
# train/non-face/graves111_156.pgm
# train/non-face/graves111_157.pgm
# train/non-face/graves111_158.pgm
# train/non-face/graves111_159.pgm
# train/non-face/graves111_16.pgm
# train/non-face/graves111_160.pgm
# train/non-face/graves111_161.pgm
# train/non-face/graves111_162.pgm
# train/non-face/graves111_163.pgm
# train/non-face/graves111_164.pgm
# train/non-face/graves111_165.pgm
# train/non-face/graves111_166.pgm
# train/non-face/graves111_167.pgm
# train/non-face/graves111_168.pgm
# train/non-face/graves111_169.pgm
# train/non-face/graves111_17.pgm
# train/non-face/graves111_170.pgm
# train/non-face/graves111_171.pgm
# train/non-face/graves111_172.pgm
# train/non-face/graves111_173.pgm
# train/non-face/graves111_174.pgm
# train/non-face/graves111_175.pgm
# train/non-face/graves111_176.pgm
# train/non-face/graves111_177.pgm
# train/non-face/graves111_178.pgm
# train/non-face/graves111_179.pgm
# train/non-face/graves111_18.pgm
# train/non-face/graves111_180.pgm
# train/non-face/graves111_181.pgm
# train/non-face/graves111_182.pgm
# train/non-face/graves111_183.pgm
# train/non-face/graves111_184.pgm
# train/non-face/graves111_185.pgm
# train/non-face/graves111_186.pgm
# train/non-face/graves111_187.pgm
# train/non-face/graves111_188.pgm
# train/non-face/graves111_189.pgm
# train/non-face/graves111_19.pgm
# train/non-face/graves111_190.pgm
# train/non-face/graves111_191.pgm
# train/non-face/graves111_192.pgm
# train/non-face/graves111_193.pgm
# train/non-face/graves111_194.pgm
# train/non-face/graves111_195.pgm
# train/non-face/graves111_196.pgm
# train/non-face/graves111_197.pgm
# train/non-face/graves111_198.pgm
# train/non-face/graves111_199.pgm
# train/non-face/graves111_2.pgm
# train/non-face/graves111_20.pgm
# train/non-face/graves111_200.pgm
# train/non-face/graves111_201.pgm
# train/non-face/graves111_202.pgm
# train/non-face/graves111_203.pgm
# train/non-face/graves111_204.pgm
# train/non-face/graves111_205.pgm
# train/non-face/graves111_206.pgm
# train/non-face/graves111_207.pgm
# train/non-face/graves111_208.pgm
# train/non-face/graves111_209.pgm
# train/non-face/graves111_21.pgm
# train/non-face/graves111_210.pgm
# train/non-face/graves111_211.pgm
# train/non-face/graves111_212.pgm
# train/non-face/graves111_213.pgm
# train/non-face/graves111_214.pgm
# train/non-face/graves111_215.pgm
# train/non-face/graves111_216.pgm
# train/non-face/graves111_217.pgm
# train/non-face/graves111_218.pgm
# train/non-face/graves111_219.pgm
# train/non-face/graves111_22.pgm
# train/non-face/graves111_220.pgm
# train/non-face/graves111_221.pgm
# train/non-face/graves111_222.pgm
# train/non-face/graves111_223.pgm
# train/non-face/graves111_224.pgm
# train/non-face/graves111_225.pgm
# train/non-face/graves111_226.pgm
# train/non-face/graves111_227.pgm
# train/non-face/graves111_23.pgm
# train/non-face/graves111_24.pgm
# train/non-face/graves111_25.pgm
# train/non-face/graves111_26.pgm
# train/non-face/graves111_27.pgm
# train/non-face/graves111_28.pgm
# train/non-face/graves111_29.pgm
# train/non-face/graves111_3.pgm
# train/non-face/graves111_30.pgm
# train/non-face/graves111_31.pgm
# train/non-face/graves111_32.pgm
# train/non-face/graves111_33.pgm
# train/non-face/graves111_34.pgm
# train/non-face/graves111_35.pgm
# train/non-face/graves111_36.pgm
# train/non-face/graves111_37.pgm
# train/non-face/graves111_38.pgm
# train/non-face/graves111_39.pgm
# train/non-face/graves111_4.pgm
# train/non-face/graves111_40.pgm
# train/non-face/graves111_41.pgm
# train/non-face/graves111_42.pgm
# train/non-face/graves111_43.pgm
# train/non-face/graves111_44.pgm
# train/non-face/graves111_45.pgm
# train/non-face/graves111_46.pgm
# train/non-face/graves111_47.pgm
# train/non-face/graves111_48.pgm
# train/non-face/graves111_49.pgm
# train/non-face/graves111_5.pgm
# train/non-face/graves111_50.pgm
# train/non-face/graves111_51.pgm
# train/non-face/graves111_52.pgm
# train/non-face/graves111_53.pgm
# train/non-face/graves111_54.pgm
# train/non-face/graves111_55.pgm
# train/non-face/graves111_56.pgm
# train/non-face/graves111_57.pgm
# train/non-face/graves111_58.pgm
# train/non-face/graves111_59.pgm
# train/non-face/graves111_6.pgm
# train/non-face/graves111_60.pgm
# train/non-face/graves111_61.pgm
# train/non-face/graves111_62.pgm
# train/non-face/graves111_63.pgm
# train/non-face/graves111_64.pgm
# train/non-face/graves111_65.pgm
# train/non-face/graves111_66.pgm
# train/non-face/graves111_67.pgm
# train/non-face/graves111_68.pgm
# train/non-face/graves111_69.pgm
# train/non-face/graves111_7.pgm
# train/non-face/graves111_70.pgm
# train/non-face/graves111_71.pgm
# train/non-face/graves111_72.pgm
# train/non-face/graves111_73.pgm
# train/non-face/graves111_74.pgm
# train/non-face/graves111_75.pgm
# train/non-face/graves111_76.pgm
# train/non-face/graves111_77.pgm
# train/non-face/graves111_78.pgm
# train/non-face/graves111_79.pgm
# train/non-face/graves111_8.pgm
# train/non-face/graves111_80.pgm
# train/non-face/graves111_81.pgm
# train/non-face/graves111_82.pgm
# train/non-face/graves111_83.pgm
# train/non-face/graves111_84.pgm
# train/non-face/graves111_85.pgm
# train/non-face/graves111_86.pgm
# train/non-face/graves111_87.pgm
# train/non-face/graves111_88.pgm
# train/non-face/graves111_89.pgm
# train/non-face/graves111_9.pgm
# train/non-face/graves111_90.pgm
# train/non-face/graves111_91.pgm
# train/non-face/graves111_92.pgm
# train/non-face/graves111_93.pgm
# train/non-face/graves111_94.pgm
# train/non-face/graves111_95.pgm
# train/non-face/graves111_96.pgm
# train/non-face/graves111_97.pgm
# train/non-face/graves111_98.pgm
# train/non-face/graves111_99.pgm

# %%
suffix = '.pgm'

train_faces = os.listdir('/content/train/face')
train_faces = [filename for filename in train_faces if filename.endswith(suffix)]

train_background = os.listdir('/content/train/non-face')
train_background = [filename for filename in train_background if filename.endswith(suffix)]

test_faces = os.listdir('/content/test/face')
test_faces = [filename for filename in test_faces if filename.endswith(suffix)]

test_background = os.listdir('/content/test/non-face')
test_background = [filename for filename in test_background if filename.endswith(suffix)]

# %%
print(f'# Train Faces: {len(train_faces)}')
print(f'# Train Back: {len(train_background)}')
print(f'# Test Faces: {len(test_faces)}')
print(f'# Test Back: {len(test_background)}')
# Out:
# # Train Faces: 2429
# # Train Back: 4548
# # Test Faces: 472
# # Test Back: 23573

# %%
# Tomaremos una fracción de los datos. Puede ajustar estos parámetros a gusto
f = 0.2
n_face = int(f*len(train_faces))
n_back = int(f*len(train_background))

# Para mantener la proporción de background en test calculamos (para mantener una proporción balanceada entre las clases (rostros y no-rostros)):
m = int(np.round(len(test_faces)*len(train_background)/len(train_faces)))

print(f'# Train Faces Sample Size: {n_face}')
print(f'# Train Back Sample Size: {n_back}')
print(f'# m: {m}')
# Out:
# # Train Faces Sample Size: 485
# # Train Back Sample Size: 909
# # m: 884

# %%
sample_train_faces = random.sample(train_faces,n_face)

Im_train = []
for filename in tqdm(sample_train_faces):
    path = '/content/train/face/' + filename
    with open(path, 'rb') as pgmf:
        image = plt.imread(pgmf)
    Im_train.append(image)

n_train_faces = len(Im_train)
y_train = [1]*n_train_faces # Cada imagen de rostro se etiqueta con un 1
# Out:
# 100%|██████████| 485/485 [00:00<00:00, 5227.27it/s]

# %%
sample_train_background = random.sample(train_background,n_back)

for filename in tqdm(sample_train_background):
    path = "/content/train/non-face/" + filename
    with open(path, 'rb') as pgmf:
        image = plt.imread(pgmf)
    Im_train.append(image)

n_train_background = len(Im_train)-n_train_faces
y_train = y_train + [0]*n_train_background # Cada imagen de no-rostro se etiqueta con un 0
# Out:
# 100%|██████████| 909/909 [00:00<00:00, 7528.07it/s]

# %%
print(f'# Train: {len(Im_train)}, {len(y_train)}')
# Out:
# # Train: 1394, 1394

# %%
Im_test = []
for filename in tqdm(test_faces):
    path = "/content/test/face/" + filename
    with open(path, 'rb') as pgmf:
        image = plt.imread(pgmf)
    Im_test.append(image)

n_test_faces = len(Im_test)
y_test = [1]*n_test_faces
# Out:
# 100%|██████████| 472/472 [00:00<00:00, 5527.64it/s]

# %%
sample_test_background = random.sample(test_background,m)

for filename in tqdm(sample_test_background):
    path = "/content/test/non-face/" + filename
    with open(path, 'rb') as pgmf:
        image = plt.imread(pgmf)
    Im_test.append(image)

n_test_background = len(Im_test)-n_test_faces
y_test = y_test + [0]*n_test_background
# Out:
# 100%|██████████| 884/884 [00:00<00:00, 5618.63it/s]

# %%
print(f'# Test: {len(Im_test)}, {len(y_test)}')
# Out:
# # Test: 1356, 1356

# %% [markdown]
# ## Histogram equalization

# %%
# Normalización de las imágenes de entrenamiento y prueba
Im_train_norm = [equalize_hist(image) for image in Im_train]
Im_test_norm = [equalize_hist(image) for image in Im_test]

# %% [markdown]
# ## Matriz de features

# %% [markdown]
# ### Calculamos y seleccionamos las mejores features en entrenamiento

# %%
X_train = [extract_feature_image(img) for img in tqdm(Im_train_norm)]
X_train = np.array(X_train)
# Out:
# 100%|██████████| 1394/1394 [04:18<00:00,  5.39it/s]

# %%
# Pueden guardar la matriz si lo desean
np.save('X_train', X_train)

# %%
# Y cargarla posteriormente
X_train = np.load('X_train.npy')

# %%
X_train.shape
# Out:
# (1394, 63960)

# %%
# Selección de características en train
print("Seleccionando las features de mayor dependencia lineal con y")
t_start = time()
# SelectPercentile: selecciona las mejores características basadas en una prueba estadística.
# f_classif: mide la dependencia lineal entre dos conjuntos de datos.
# percentile=1: Selecciona el 1% de las mejores características.
# fit(X_train, y_train): Ajusta el selector de características a los datos de entrenamiento X_train y y_train.
# get_support(indices=True): Obtiene los índices de las características seleccionadas.
f_indices = SelectPercentile(f_classif, percentile=1).fit(X_train, y_train).get_support(indices=True)
t = time() - t_start
X_train = X_train[:,f_indices]
print("Seleccionadas %d features potenciales" % X_train.shape[1])
print(f'Tiempo: {t} segundos')
# Out:
# Seleccionando las features de mayor dependencia lineal con y
# Seleccionadas 640 features potenciales
# Tiempo: 1.2167468070983887 segundos

# %% [markdown]
# ### Calculamos dichas features para test

# %%
# haar_like_feature_coord(): genera coordenadas y tipos de características Haar para una ventana de búsqueda especificada. En este caso 19x19 píxeles.
feature_coord, feature_type = haar_like_feature_coord(width=19,
                                                      height=19,
                                                      )

# %%
t_start = time()
X_test = [extract_feature_image(img,
                                feature_type=feature_type[f_indices],
                                feature_coord=feature_coord[f_indices]) for img in tqdm(Im_test_norm)]
t = time() - t_start
X_test = np.array(X_test)
# Out:
# 100%|██████████| 1356/1356 [00:01<00:00, 861.07it/s]

# %%
print(f'Tiempo: {t} segundos')
print(f'Shape X_test: {X_test.shape}')
# Out:
# Tiempo: 1.5834944248199463 segundos
# Shape X_test: (1356, 640)

# %%
# Entrenamiento del Modelo Random Forest
from sklearn.ensemble import RandomForestClassifier

# Crear el clasificador Random Forest
rf_classifier = RandomForestClassifier(n_estimators=600, random_state=42)

# Entrenar el clasificador con el conjunto de entrenamiento y las características extraídas
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=600, random_state=42)

# %%
# Evaluación del Modelo
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Predecir las etiquetas de las imágenes de prueba
y_pred = rf_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Precisión del modelo:", accuracy)

print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))

print("\nMatriz de confusión:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Precisión del modelo: 0.7588495575221239
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0       0.74      0.98      0.84       884
#            1       0.88      0.35      0.51       472
#
#     accuracy                           0.76      1356
#    macro avg       0.81      0.66      0.67      1356
# weighted avg       0.79      0.76      0.72      1356
#
#
# Matriz de confusión:
# [[862  22]
#  [305 167]]
